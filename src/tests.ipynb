# %%
from pygdsm import GlobalSkyModel16
gsm = GlobalSkyModel16('Hz')

# %%
_map = gsm.generate(1e9)
_map.nside
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 2
#       1 _map = gsm.generate(1e9)
# ----> 2 _map.nside
#
# AttributeError: 'numpy.ndarray' object has no attribute 'nside'

# %%
from CHORD_Sensitivity.telescope import Telescope
from CHORD_Sensitivity.sky_map import SkyMap

# %%
delta_nu = 1e6  # Hz
freqs = [1, 1.1]  # GHz

sky_map = SkyMap("CHORD")
sky_map.plot_sky_noise(delta_nu=delta_nu, freqs=freqs)
# Out:
# /Users/duncancs/Documents/Research/chord_rrl/CHORD_Sensitivity/src/CHORD_Sensitivity/telescope.py:203: RuntimeWarning: divide by zero encountered in divide
#   term2 = np.sqrt((2 * np.sqrt(2 * np.log(2)) * OMEGA * np.cos(np.radians(dec_deg))) /
